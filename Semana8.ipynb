# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

img = cv.imread("C:/Users/laelm/OneDrive/Escritorio/1238/procesamiento de imagenes/Mapache.jpeg",0)

# %%
plt.imshow(img, cmap="gray")

# %%
img_aux = img.copy()

# %%
filas, columnas = img.shape

# %%
for f in range(filas):
    for c in range(columnas):
        if img[f,c] >= 128:
            img_aux[f,c] = 255
        else:
            img_aux[f,c] = 0
            
plt.imshow(img_aux, cmap="gray")

# %%
plt.imshow(cv.threshold(img, 128, 1, cv.THRESH_BINARY)[1], cmap="gray")

# %%
np.unique(img_aux)
# Out:
# array([  0, 255], dtype=uint8)

# %%
img_bin = cv.threshold(img, 128, 1, cv.THRESH_BINARY)[1]
plt.imshow(img_bin, cmap = "gray")

# %%
np.unique(img_bin)
plt.imshow(img_bin, cmap = "gray")

# %%
#cv.imwrite("Binaria.jpg")

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\laelm\OneDrive\Escritorio\1238\procesamiento de imagenes\Semana8.ipynb Celda 11 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/laelm/OneDrive/Escritorio/1238/procesamiento%20de%20imagenes/Semana8.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> img_neg = img.copy()
#
# NameError: name 'img' is not defined
