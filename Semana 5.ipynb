# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
#traer la imagen 
img = cv.imread('C:\\Users\\laelm\\OneDrive\\Escritorio\\procesamiento de imagenes\\a.png')[:,:,::-1]

# %%
img.shape
# Out:
# (270, 394, 3)

# %%
plt.imshow(img)

# %%
#RGB
canal_R = img[:,:,0]
canal_G = img[:,:,1]
canal_B = img[:,:,2]

# %%
# canal_R, canal_G, canal_B = cv.split(img)

# %%
canal_B.shape
# Out:
# (270, 394)

# %%
plt.subplot(131); plt.imshow(canal_R, cmap = 'gray'); plt.title('canal_R')
#plt.show()
plt.subplot(132); plt.imshow(canal_G, cmap = 'gray'); plt.title('canal_G')
#plt.show()
plt.subplot(133); plt.imshow(canal_B, cmap = 'gray'); plt.title('canal_B')
#plt.show()
#13 por 1 fila 3 columnas 1,2,3 por el numero de elementos
# Out:
# Text(0.5, 1.0, 'canal_B')

# %%
img[:, :, (0,2)] = 0

# %%
img.shape
# Out:
# (270, 394, 3)

# %%
plt.imshow(img, cmap='gray')

# %%
    chl1 = np.ones((300,300), dtype=np.uint8) * 255
    chl2 = np.zeros((300,300), dtype=np.uint8)
    chl3 = np.zeros((300,300), dtype=np.uint8)

# %%
#cb.split
img2 = (cv.merge((chl1, chl2, chl3)))

# %%
type(img2)
# Out:
# numpy.ndarray

# %%
img2.shape
# Out:
# (300, 300, 3)

# %%
plt.imshow(img2)

# %%
cv.imwrite("roja.jpg", img2[:,:,::-1])
# Out:
# True

# %%
chl1 = np.ones((300,300), dtype=np.uint8) * 255
chl2 = np.ones((300,300), dtype=np.uint8) * 255
chl3 = np.ones((300,300), dtype=np.uint8)

# %%
#cb.split
img3 = (cv.merge((chl1, chl2, chl3)))

# %%
type(img3)
# Out:
# numpy.ndarray

# %%
img3.shape
# Out:
# (300, 300, 3)

# %%
plt.imshow(img3)

# %%
cv.imwrite("amarilla.jpg", img3[:,:,::-1])
# Out:
# True

# %%
chl1 = np.ones((300,300), dtype=np.uint8) * 148
chl2 = np.ones((300,300), dtype=np.uint8) * 42
chl3 = np.ones((300,300), dtype=np.uint8) * 187

# %%
#cb.split
img4 = (cv.merge((chl1, chl2, chl3)))

# %%
type(img4)
# Out:
# numpy.ndarray

# %%
img4.shape
# Out:
# (300, 300, 3)

# %%
plt.imshow(img4)

# %%
cv.imwrite("morada.jpg", img4[:,:,::-1])
# Out:
# True
