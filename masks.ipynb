# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

# %%
img = cv.imread("Mapache.jpeg")[:,:,::-1]
plt.imshow(img)

# %%
np.zeros_like(img).shape
# Out:
# (750, 750, 3)

# %%
mask = np.zeros_like(img)
mask[300:600, 180:550] = 255

# %%
plt.imshow(np.hstack((img, mask)))

# %%
plt.imshow(np.bitwise_and(img, mask))

# %%
img_w_mask = mask & img

# %%
mask.dtype
# Out:
# dtype('uint8')

# %%
plt.imshow(img_w_mask)

# %%
'''for i in range(3):
    histograma = cv.calcHist([img], [i], mask, histsize=[256], range=[0, 256])
    plt.plot(histograma)'''
# Out:
# 'for i in range(3):\n    histograma = cv.calcHist([img], [i], mask, histsize=[256], range=[0, 256])\n    plt.plot(histograma)'

# %%
for n, i in enumerate(["r", "g", "b"]):
    histograma = cv.calcHist([img], [n], mask[:,:,0], [256], [0, 256])
    plt.plot(histograma, i)
