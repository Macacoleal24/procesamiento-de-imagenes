# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv.imread("C:/Users/laelm/OneDrive/Escritorio/1238/procesamiento de imagenes/Mapache.jpeg")

# %%
plt.imshow(img, cmap = "gray")
